# %%
# import libraries and functions
import sys
import os
from pathlib import Path

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from src.utils.kg.kg_loader import load_kg_from_yaml
from src.utils.output.graph_viz import visualize_graph
from src.utils.kg.kg_debug import print_graph_triples

# %%
# Load the knowledge graph from the YAML file
G = load_kg_from_yaml()

# Print the number of nodes and edges in the graph
print(f"🧠 Nodes: {G.number_of_nodes()}")
print(f"🔗 Edges: {G.number_of_edges()}")

# Print sample of graph triples
print_graph_triples(G, include_metadata=True, max_examples=20)
# Out:
# 🧠 Nodes: 179
# 🔗 Edges: 220
#
# 📊 Knowledge Graph Triples:
# (Left Field) --[hasResponsibilityIn]--> (0 outs, runner on 1st)  [meta: source: llm]
# (Left Field) --[hasResponsibilityIn]--> (1 out, runners on 1st and 2nd)  [meta: source: llm]
# (Left Field) --[hasResponsibilityIn]--> (2 outs, runner on 3rd)  [meta: source: llm]
# (Left Field) --[hasResponsibilityIn]--> (1 out, runner on 2nd)  [meta: source: llm]
# (Left Field) --[hasResponsibilityIn]--> (0 outs, runners on 2nd and 3rd)  [meta: source: llm]
# (0 outs, runner on 1st) --[triggers]--> (Fly ball to Left Field)  [meta: source: llm]
# (0 outs, runner on 1st) --[triggers]--> (Fly ball hit to Right Field)  [meta: source: llm]
# (0 outs, runner on 1st) --[triggers]--> (Line drive hit to Third Base)  [meta: source: llm]
# (0 outs, runner on 1st) --[triggers]--> (Ground ball hit to the shortstop)  [meta: source: llm]
# (0 outs, runner on 1st) --[triggers]--> (Ground ball hit to First Base)  [meta: source: llm]
# ...
